# %% [markdown]
# # W10: Paper-to-Code Submission Notebook
#
# Terkait: **Bab 10 - Paper Reading & Implementation**
#
# Notebook ini dipakai setelah diskusi paket paper di kelas. Tujuannya bukan mencari paper dari nol, tetapi mengubah hasil diskusi menjadi rencana eksperimen, reproduksi kecil, parity check, satu ablasi unik, dan laporan singkat.
#
# ## Luaran
# - Ringkasan klaim paper dan bukti utama.
# - Rencana reproduksi yang jelas.
# - Parameter yang dibuat tetap.
# - Smoke test implementasi.
# - Tabel hasil reproduksi dan parity check.
# - Satu ablasi unik yang tidak ada di paper.
# - Kesimpulan pendek tentang klaim paper.

# %% [markdown]
# ## Daftar Paket
#
# Pilih satu paket.
#
# | Packet | Domain | Paper |
# |---|---|---|
# | W10-01 | Image | Colorful Cutout |
# | W10-02 | NLP | Adverb Deletion |
# | W10-03 | Tabular | TabM |
# | W10-04 | Tabular | GRANDE |
# | W10-05 | Time Series | SOFTS |
# | W10-06 | Time Series | ModernTCN |
# | W10-07 | Time Series | TimeMixer |
# | W10-08 | Time Series | iTransformer |

# %% [markdown]
# ## 1. Packet yang Dipilih
#
# Isi bagian ini sebelum coding.
#
# | Bagian | Isi |
# |---|---|
# | Packet ID |  |
# | Judul paper |  |
# | Domain |  |
# | Link paper |  |
# | Dataset reproduksi |  |
# | Metode utama |  |
# | Baseline utama |  |

# %% [markdown]
# ## 2. Klaim Paper
#
# Tulis singkat.
#
# | Pertanyaan | Jawaban |
# |---|---|
# | Klaim utama paper dalam satu kalimat |  |
# | Bukti utama di paper |  |
# | Tabel/gambar/hasil paper yang akan dibandingkan |  |
# | Bagian eksperimen yang sulit disamakan |  |
# | Batas klaim yang perlu hati-hati |  |

# %% [markdown]
# ## 3. Rencana Eksperimen
#
# Gunakan paket sebagai titik awal. Boleh revisi setelah membaca paper, tetapi tulis alasannya.
#
# | No | Eksperimen | Yang berubah | Untuk mengecek |
# |---|---|---|---|
# | 1 | Baseline |  |  |
# | 2 | Reproduksi paper |  |  |
# | 3 | Ablasi dari paper / ablasi reproduksi |  |  |
# | 4 | Ablasi unik |  |  |
#
# Alasan revisi dari paket, jika ada:

# %% [markdown]
# ## 4. Parameter yang Dibuat Tetap
#
# Isi satu nilai konkret per baris. Jangan tulis pilihan dengan `/` di bagian ini.
#
# | Parameter | Nilai |
# |---|---|
# | Dataset reproduksi |  |
# | Model |  |
# | Epoch |  |
# | Optimizer |  |
# | Learning rate |  |
# | Batch size |  |
# | Seed |  |
# | Split |  |
# | Metrik |  |

# %% [markdown]
# ## 5. Implementasi dan Smoke Test
#
# Sebutkan file/fungsi yang dibuat atau diubah. Smoke test dilakukan sebelum training penuh.
#
# | Smoke test | Hasil |
# |---|---|
# | Data loader mengeluarkan batch dengan shape benar |  |
# | Forward pass berjalan |  |
# | Loss finite pada batch kecil |  |
# | Metrik bisa dihitung |  |
# | Satu epoch pendek berjalan tanpa error |  |

# %%
# Isi dengan import, konfigurasi, dan helper yang dipakai.
# Simpan seed, device, dataset, model, dan parameter training di sini.

SEED = 42
PACKET_ID = "W10-__"
PAPER_TITLE = ""
DATASET_NAME = ""
METRIC_NAME = ""

# %%
# TODO: tulis atau panggil implementasi minimal di sini.
# Contoh isi:
# - load dataset
# - buat model/baseline
# - training loop atau pemanggilan script resmi
# - fungsi evaluasi

# %% [markdown]
# ## 6. Hasil Reproduksi
#
# Isi dengan hasil yang benar-benar dijalankan.
#
# | Eksperimen | Metrik 1 | Metrik 2 | Catatan |
# |---|---:|---:|---|
# | Baseline |  |  |  |
# | Reproduksi paper |  |  |  |
# | Ablasi reproduksi |  |  |  |

# %% [markdown]
# ## 7. Parity Check
#
# Bandingkan hasil kalian dengan paper. Tidak harus sama persis, tetapi harus jelas apakah arah hasilnya mengikuti paper.
#
# | Bagian | Catatan |
# |---|---|
# | Angka/pola hasil di paper |  |
# | Angka/pola hasil reproduksi |  |
# | Sama arah dengan paper? |  |
# | Selisih utama |  |
# | Dugaan penyebab gap |  |

# %% [markdown]
# ## 8. Ablasi Unik
#
# Pilih satu ablasi yang tidak ada di paper. Tujuannya menguji batas klaim paper.
#
# | Bagian | Isi |
# |---|---|
# | Ablasi unik yang dipilih |  |
# | Kenapa ablasi ini menarik |  |
# | Yang dibuat tetap |  |
# | Yang diubah |  |
# | Ekspektasi sebelum eksperimen |  |

# %%
# TODO: jalankan ablasi unik di sini.
# Pastikan hanya satu faktor utama yang berubah dibanding setup reproduksi.

# %% [markdown]
# ## 9. Hasil Ablasi Unik
#
# | Eksperimen | Metrik 1 | Metrik 2 | Interpretasi |
# |---|---:|---:|---|
# | Reproduksi paper |  |  |  |
# | Ablasi unik |  |  |  |
#
# Kesimpulan dari ablasi:

# %% [markdown]
# ## 10. Kesimpulan Pendek
#
# Jawab dalam 1-2 paragraf.
#
# 1. Apakah hasil kalian mendukung klaim paper?
# 2. Bagian mana yang paling sulit direproduksi?
# 3. Detail apa yang paling berpengaruh terhadap hasil?
# 4. Jika eksperimen ini dilanjutkan satu minggu lagi, apa yang akan diperbaiki?

# %% [markdown]
# ## Opsional: Paper arXiv Pilihan Sendiri
#
# Bagian ini hanya untuk latihan lanjut. Gunakan jika ingin mengulang seluruh langkah dengan paper pilihan sendiri, seperti workflow peneliti: cari paper, nilai kelayakan, pilih dataset, reproduksi, parity check, lalu buat satu ablasi unik.
#
# ### Kriteria paper
# - Tahun 2024 ke atas.
# - Ada dataset publik.
# - Ada baseline yang jelas.
# - Klaim utama bisa diuji dengan eksperimen kecil.
# - Tidak membutuhkan data privat, multi-GPU, atau training model besar dari nol.
# - Ada kode resmi atau metode cukup sederhana untuk diimplementasikan.
#
# ### Catatan kurasi
#
# | Bagian | Isi |
# |---|---|
# | Query pencarian |  |
# | Top 3 paper yang dipertimbangkan |  |
# | Paper yang dipilih |  |
# | Alasan memilih paper ini |  |
# | Alasan menolak paper lain |  |
# | Dataset reproduksi |  |
# | Baseline |  |
# | Risiko implementasi |  |
#
# Setelah bagian ini, ulangi langkah 2-10 di atas untuk paper pilihan sendiri.
